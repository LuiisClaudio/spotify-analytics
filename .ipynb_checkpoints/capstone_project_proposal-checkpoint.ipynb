# %%
#import kagglehub

# Download latest version
#path = kagglehub.dataset_download("solomonameh/spotify-music-dataset")

#print("Path to dataset files:", path)

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
dir_path = "C:\\Users\\junio\\.cache\\kagglehub\\datasets\\solomonameh\\spotify-music-dataset\\versions\\1\\"
df_high = pd.read_csv(dir_path + "high_popularity_spotify_data.csv")
df_low = pd.read_csv(dir_path + "low_popularity_spotify_data.csv")
df_high.head()
# Out:
#    energy    tempo  danceability playlist_genre  loudness  liveness  valence  \
# 0   0.592  157.969         0.521            pop    -7.777     0.122    0.535
# 1   0.507  104.978         0.747            pop   -10.171     0.117    0.438
# 2   0.808  108.548         0.554            pop    -4.169     0.159    0.372
# 3   0.910  112.966         0.670            pop    -4.070     0.304    0.786
# 4   0.783  149.027         0.777            pop    -4.477     0.355    0.939
#
#             track_artist  time_signature  speechiness  ...  instrumentalness  \
# 0  Lady Gaga, Bruno Mars               3       0.0304  ...            0.0000
# 1          Billie Eilish               4       0.0358  ...            0.0608
# 2          Gracie Abrams               4       0.0368  ...            0.0000
# 3      Sabrina Carpenter               4       0.0634  ...            0.0000
# 4       ROSÉ, Bruno Mars               4       0.2600  ...            0.0000
#
#            track_album_id mode key duration_ms acousticness  \
# 0  10FLjwfpbxLmW8c25Xyc2N    0   6      251668       0.3080
# 1  7aJuG4TFXa2hmE4z1yxc3n    1   2      210373       0.2000
# 2  0hBRqPYPXhr1RkTDG3n4Mk    1   1      166300       0.2140
# 3  4B4Elma4nNDUyl6D5PvQkj    0   0      157280       0.0939
# 4  2IYQwwgxgOIn7t3iF6ufFD    0   0      169917       0.0283
#
#                        id playlist_subgenre            type  \
# 0  2plbrEY59IikOBgBGLjaoe        mainstream  audio_features
# 1  6dOtVTDdiauQNBQEDOtlAB        mainstream  audio_features
# 2  7ne4VBA60CxGM75vw0EYad        mainstream  audio_features
# 3  1d7Ptw3qYcfpdLNL5REhtJ        mainstream  audio_features
# 4  5vNRhkKd0yEAg8suGBpjeY        mainstream  audio_features
#
#               playlist_id
# 0  37i9dQZF1DXcBWIGoYBM5M
# 1  37i9dQZF1DXcBWIGoYBM5M
# 2  37i9dQZF1DXcBWIGoYBM5M
# 3  37i9dQZF1DXcBWIGoYBM5M
# 4  37i9dQZF1DXcBWIGoYBM5M
#
# [5 rows x 29 columns]

# %%
df_low.head()
# Out:
#    time_signature  track_popularity  speechiness  danceability  playlist_name  \
# 0             4.0                23       0.0393         0.636  Rock Classics
# 1             4.0                53       0.0317         0.572  Rock Classics
# 2             4.0                55       0.0454         0.591  Rock Classics
# 3             4.0                64       0.1010         0.443  Jazz Classics
# 4             4.0                62       0.0298         0.685  Jazz Classics
#
#                        track_artist  duration_ms  energy playlist_genre  \
# 0      Creedence Clearwater Revival     138053.0   0.746           rock
# 1                         Van Halen     241600.0   0.835           rock
# 2                      Stevie Nicks     329413.0   0.804           rock
# 3  Ella Fitzgerald, Louis Armstrong     185160.0   0.104           jazz
# 4                    Galt MacDermot     205720.0   0.472           jazz
#
#   playlist_subgenre  ...          track_album_id             playlist_id  \
# 0           classic  ...  4A8gFwqd9jTtnsNwUu3OQx  37i9dQZF1DWXRqgorJj26U
# 1           classic  ...  2c965LEDRNrXXCeBOAAwns  37i9dQZF1DWXRqgorJj26U
# 2           classic  ...  3S404OgKoVQSJ3xXrDVlp8  37i9dQZF1DWXRqgorJj26U
# 3           classic  ...  1y5KGkUKO0NG32MhIIagCA  37i9dQZF1DXbITWG1ZJKYt
# 4           classic  ...  6f4b9wVTkKAf096k4XG6x5  37i9dQZF1DXbITWG1ZJKYt
#
#                  track_id valence  key    tempo loudness acousticness  \
# 0  5e6x5YRnMJIKvYpZxLqdpH   0.432  0.0  132.310   -3.785       0.0648
# 1  5FqYA8KfiwsQvyBI4IamnY   0.795  0.0  129.981   -6.219       0.1710
# 2  5LNiqEqpDc8TuqPy79kDBu   0.658  0.0  111.457   -7.299       0.3270
# 3  78MI7mu1LV1k4IA2HzKmHe   0.394  0.0   76.474  -17.042       0.9130
# 4  6MN6yRVriszuyAVlyF8ndB   0.475  9.0   80.487   -9.691       0.7850
#
#    liveness                                   track_album_name
# 0    0.1730  The Long Road Home - The Ultimate John Fogerty...
# 1    0.0702                                     The Collection
# 2    0.0818                       Bella Donna (Deluxe Edition)
# 3    0.1910                                         Love, Ella
# 4    0.2240                  Shapes of Rhythm/Woman Is Sweeter
#
# [5 rows x 29 columns]

# %%
df_high_columns = df_high.columns.sort_values()
#print(df_high_columns)
#df_high_columns = df_high_columns
# Out:
# Index(['acousticness', 'analysis_url', 'danceability', 'duration_ms', 'energy',
#        'id', 'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
#        'playlist_genre', 'playlist_id', 'playlist_name', 'playlist_subgenre',
#        'speechiness', 'tempo', 'time_signature', 'track_album_id',
#        'track_album_name', 'track_album_release_date', 'track_artist',
#        'track_href', 'track_id', 'track_name', 'track_popularity', 'type',
#        'uri', 'valence'],
#       dtype='object')

# %%
df_low_columns = df_low.columns.sort_values()
#print(df_low_columns)
#df_high_columns = df_high_columns
# Out:
# Index(['acousticness', 'analysis_url', 'danceability', 'duration_ms', 'energy',
#        'id', 'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
#        'playlist_genre', 'playlist_id', 'playlist_name', 'playlist_subgenre',
#        'speechiness', 'tempo', 'time_signature', 'track_album_id',
#        'track_album_name', 'track_album_release_date', 'track_artist',
#        'track_href', 'track_id', 'track_name', 'track_popularity', 'type',
#        'uri', 'valence'],
#       dtype='object')

# %%
#Both datasets have the same features
print(df_high_columns == df_low_columns)
# Out:
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True]

# %%
#df_high = df_high[df_high_columns]
df_low = df_low[df_high.columns]
df_low.head()
# Out:
#    energy    tempo  danceability playlist_genre  loudness  liveness  valence  \
# 0   0.746  132.310         0.636           rock    -3.785    0.1730    0.432
# 1   0.835  129.981         0.572           rock    -6.219    0.0702    0.795
# 2   0.804  111.457         0.591           rock    -7.299    0.0818    0.658
# 3   0.104   76.474         0.443           jazz   -17.042    0.1910    0.394
# 4   0.472   80.487         0.685           jazz    -9.691    0.2240    0.475
#
#                        track_artist  time_signature  speechiness  ...  \
# 0      Creedence Clearwater Revival             4.0       0.0393  ...
# 1                         Van Halen             4.0       0.0317  ...
# 2                      Stevie Nicks             4.0       0.0454  ...
# 3  Ella Fitzgerald, Louis Armstrong             4.0       0.1010  ...
# 4                    Galt MacDermot             4.0       0.0298  ...
#
#    instrumentalness          track_album_id mode  key duration_ms  \
# 0          0.290000  4A8gFwqd9jTtnsNwUu3OQx  1.0  0.0    138053.0
# 1          0.000377  2c965LEDRNrXXCeBOAAwns  1.0  0.0    241600.0
# 2          0.000006  3S404OgKoVQSJ3xXrDVlp8  1.0  0.0    329413.0
# 3          0.000000  1y5KGkUKO0NG32MhIIagCA  1.0  0.0    185160.0
# 4          0.284000  6f4b9wVTkKAf096k4XG6x5  0.0  9.0    205720.0
#
#   acousticness                      id playlist_subgenre            type  \
# 0       0.0648  5e6x5YRnMJIKvYpZxLqdpH           classic  audio_features
# 1       0.1710  5FqYA8KfiwsQvyBI4IamnY           classic  audio_features
# 2       0.3270  5LNiqEqpDc8TuqPy79kDBu           classic  audio_features
# 3       0.9130  78MI7mu1LV1k4IA2HzKmHe           classic  audio_features
# 4       0.7850  6MN6yRVriszuyAVlyF8ndB           classic  audio_features
#
#               playlist_id
# 0  37i9dQZF1DWXRqgorJj26U
# 1  37i9dQZF1DWXRqgorJj26U
# 2  37i9dQZF1DWXRqgorJj26U
# 3  37i9dQZF1DXbITWG1ZJKYt
# 4  37i9dQZF1DXbITWG1ZJKYt
#
# [5 rows x 29 columns]

# %%
# Combine both datasets
df = pd.concat([df_high, df_low], ignore_index=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4831 entries, 0 to 4830
# Data columns (total 29 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   energy                    4830 non-null   float64
#  1   tempo                     4830 non-null   float64
#  2   danceability              4830 non-null   float64
#  3   playlist_genre            4831 non-null   object
#  4   loudness                  4830 non-null   float64
#  5   liveness                  4830 non-null   float64
#  6   valence                   4830 non-null   float64
#  7   track_artist              4831 non-null   object
#  8   time_signature            4830 non-null   float64
#  9   speechiness               4830 non-null   float64
#  10  track_popularity          4831 non-null   int64
#  11  track_href                4830 non-null   object
#  12  uri                       4830 non-null   object
#  13  track_album_name          4830 non-null   object
#  14  playlist_name             4831 non-null   object
#  15  analysis_url              4830 non-null   object
#  16  track_id                  4831 non-null   object
#  17  track_name                4831 non-null   object
#  18  track_album_release_date  4831 non-null   object
#  19  instrumentalness          4830 non-null   float64
#  20  track_album_id            4831 non-null   object
#  21  mode                      4830 non-null   float64
#  22  key                       4830 non-null   float64
#  23  duration_ms               4830 non-null   float64
#  24  acousticness              4830 non-null   float64
#  25  id                        4830 non-null   object
#  26  playlist_subgenre         4831 non-null   object
#  27  type                      4830 non-null   object
#  28  playlist_id               4831 non-null   object
# dtypes: float64(13), int64(1), object(15)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#             energy        tempo  danceability     loudness     liveness  \
# count  4830.000000  4830.000000   4830.000000  4830.000000  4830.000000
# mean      0.586691   118.269293      0.622311    -9.281627     0.167613
# std       0.246263    28.512615      0.187706     7.129396     0.124429
# min       0.000202    48.232000      0.058900   -48.069000     0.021000
# 25%       0.442250    96.063000      0.525000   -10.297750     0.095400
# 50%       0.633000   118.059500      0.653000    -7.191000     0.118000
# 75%       0.777000   136.723500      0.758000    -5.336750     0.195000
# max       0.998000   241.426000      0.979000     1.318000     0.979000
#
#            valence  time_signature  speechiness  track_popularity  \
# count  4830.000000     4830.000000  4830.000000       4831.000000
# mean      0.481930        3.936646     0.101738         54.761126
# std       0.258036        0.409712     0.101032         19.828573
# min       0.029600        1.000000     0.021900         11.000000
# 25%       0.275000        4.000000     0.038600         41.000000
# 50%       0.483000        4.000000     0.056100         56.000000
# 75%       0.690000        4.000000     0.118000         72.000000
# max       0.987000        5.000000     0.927000        100.000000
#
#        instrumentalness         mode          key   duration_ms  acousticness
# count       4830.000000  4830.000000  4830.000000  4.830000e+03   4830.000000
# mean           0.201053     0.562112     5.233333  2.061508e+05      0.341217
# std            0.351918     0.496178     3.580857  8.174556e+04      0.325382
# min            0.000000     0.000000     0.000000  3.537500e+04      0.000004
# 25%            0.000000     0.000000     2.000000  1.590000e+05      0.052925
# 50%            0.000091     1.000000     5.000000  1.948665e+05      0.224500
# 75%            0.200500     1.000000     8.000000  2.334780e+05      0.590000
# max            0.991000     1.000000    11.000000  1.355260e+06      0.996000

# %%
df.isnull().sum()
# Out:
# energy                      1
# tempo                       1
# danceability                1
# playlist_genre              0
# loudness                    1
# liveness                    1
# valence                     1
# track_artist                0
# time_signature              1
# speechiness                 1
# track_popularity            0
# track_href                  1
# uri                         1
# track_album_name            1
# playlist_name               0
# analysis_url                1
# track_id                    0
# track_name                  0
# track_album_release_date    0
# instrumentalness            1
# track_album_id              0
# mode                        1
# key                         1
# duration_ms                 1
# acousticness                1
# id                          1
# playlist_subgenre           0
# type                        1
# playlist_id                 0
# dtype: int64

# %%
df = df.dropna()
#df.isnull().sum()
